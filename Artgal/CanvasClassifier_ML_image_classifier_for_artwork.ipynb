# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions


# Load and preprocess an image
img_path = '/content/fish.jpeg'  # Replace with your image path
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)


# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')
# Predict class probabilities
preds = model.predict(x)
# Decode the predictions
predicted_labels = decode_predictions(preds, top=1)[0]
# Print the top predicted label and its probability
label, description, probability = predicted_labels[0]
print(f"Predicted Label: {label} ({description})")
print(f"Probability: {probability:.4f}")

# Optionally, you can visualize the original image
plt.imshow(img)
plt.axis('off')
plt.title('Original Image')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fcc1ce52dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# Predicted Label: n01440764 (tench)
# Probability: 0.5026

# %%
# Load and preprocess an image
img_path = '/content/Realism2.jpg'  # Replace with your image path
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)


# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')
# Predict class probabilities
preds = model.predict(x)
# Decode the predictions
predicted_labels = decode_predictions(preds, top=1)[0]
# Print the top predicted label and its probability
label, description, probability = predicted_labels[0]
print(f"Predicted Label: {label} ({description})")
print(f"Probability: {probability:.4f}")

# Optionally, you can visualize the original image
plt.imshow(img)
plt.axis('off')
plt.title('Original Image')
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fcc1ca40b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# Predicted Label: n04200800 (shoe_shop)
# Probability: 0.5408

# %%
# Load and preprocess an image
img_path = '/content/Realism1.jpg'  # Replace with your image path
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)


# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')
# Predict class probabilities
preds = model.predict(x)
# Decode the predictions
predicted_labels = decode_predictions(preds, top=1)[0]
# Print the top predicted label and its probability
label, description, probability = predicted_labels[0]
print(f"Predicted Label: {label} ({description})")
print(f"Probability: {probability:.4f}")

# Optionally, you can visualize the original image
plt.imshow(img)
plt.axis('off')
plt.title('Original Image')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Label: n02389026 (sorrel)
# Probability: 0.8099

# %%
# Load and preprocess an image
img_path = '/content/Abstract_Art3.jpg'  # Replace with your image path
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)


# Load the pre-trained ResNet50 model
model = ResNet50(weights='imagenet')
# Predict class probabilities
preds = model.predict(x)
# Decode the predictions
predicted_labels = decode_predictions(preds, top=1)[0]
# Print the top predicted label and its probability
label, description, probability = predicted_labels[0]
print(f"Predicted Label: {label} ({description})")
print(f"Probability: {probability:.4f}")

# Optionally, you can visualize the original image
plt.imshow(img)
plt.axis('off')
plt.title('Original Image')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Label: n01910747 (jellyfish)
# Probability: 0.3901

# %% [markdown]
# **CONLUSION:** Model accuracy is decent w.r.t to objects present in the artwork, but has to be fine-tuned for abstract art.
